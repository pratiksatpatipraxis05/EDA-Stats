# %%
# import python libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
filepath = "E:\Data Analysis Projects\Diwali Sales EDA\Diwali_sales.csv"
df = pd.read_csv(filepath)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# 2  23924.0     NaN       NaN
# 3  23912.0     NaN       NaN
# 4  23877.0     NaN       NaN

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.sample(frac=0.1)
# Out:
#        User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 8807   1002000    Lycoris  P00159542      F     18-25   18               0
# 2617   1000957   Goldenen  P00329642      F     36-45   41               1
# 10184  1003808   Vishakha  P00168442      F     26-35   34               0
# 4327   1006033      Wener  P00028442      F     51-55   53               0
# 1886   1003661    Nandita  P00118742      F     36-45   42               0
# ...        ...        ...        ...    ...       ...  ...             ...
# 7667   1000169    Etezadi  P00118042      F     26-35   26               1
# 9408   1004090     percer  P00233442      M       55+   63               1
# 6421   1004213    Workman  P00293042      M     36-45   37               0
# 4179   1004572  Cassandra  P00191642      M      0-17   13               1
# 5288   1002091    Prichep  P00336042      M     36-45   41               1
#
#                   State      Zone   Occupation       Product_Category  Orders  \
# 8807     Andhra Pradesh  Southern       Retail     Clothing & Apparel       1
# 2617     Andhra Pradesh  Southern      Banking           Games & Toys       4
# 10184       Maharashtra   Western    IT Sector        Household items       3
# 4327          Karnataka  Southern         Govt           Games & Toys       2
# 1886     Andhra Pradesh  Southern   Healthcare                   Food       2
# ...                 ...       ...          ...                    ...     ...
# 7667          Rajasthan  Northern   Healthcare     Clothing & Apparel       3
# 9408      Uttar Pradesh   Central       Lawyer       Footwear & Shoes       3
# 6421     Andhra Pradesh  Southern  Hospitality  Electronics & Gadgets       4
# 4179     Madhya Pradesh   Central       Lawyer  Electronics & Gadgets       2
# 5288   Himachal Pradesh  Northern     Aviation     Clothing & Apparel       3
#
#         Amount  Status  unnamed1
# 8807    5268.0     NaN       NaN
# 2617   13111.0     NaN       NaN
# 10184   3124.0     NaN       NaN
# 4327    9910.0     NaN       NaN
# 1886   15664.0     NaN       NaN
# ...        ...     ...       ...
# 7667    6856.0     NaN       NaN
# 9408    4144.0     NaN       NaN
# 6421    7830.0     NaN       NaN
# 4179    9995.0     NaN       NaN
# 5288    8572.0     NaN       NaN
#
# [1125 rows x 15 columns]

# %%
df.drop(['unnamed1','Status'], axis=1, inplace = True)
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# drop null values
df.dropna(inplace=True)

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
# Changed the amount data type to int
df['Amount'] = df['Amount'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  int32
# dtypes: int32(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# use describe() for specific columns
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# ### Exploratory data analysis

# %% [markdown]
# #### Gender

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  Amount
# 0     Maharashtra   Western       Healthcare             Auto       1   23952
# 1  Andhra Pradesh  Southern             Govt             Auto       3   23934
# 2   Uttar Pradesh   Central       Automobile             Auto       3   23924
# 3       Karnataka  Southern     Construction             Auto       2   23912
# 4         Gujarat   Western  Food Processing             Auto       2   23877

# %%
# plotting a bar chart for Gender and it's count

ax = sns.countplot(x = 'Gender',data = df)

#ax.bar_label(bars)
plt.show()

# %%
# plotting a bar chart for gender vs total amount

sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Gender',y= 'Amount' ,data = sales_gen)

# %%
# plotting a bar chart for gender vs total amount ---Slightly different code
sales_gen2 = df.groupby(['Gender'], as_index=False)['Amount'].sum()
sns.barplot(x = 'Gender',y= 'Amount' ,data = sales_gen2)
plt.show()

# %% [markdown]
# #### Age

# %%
plt.figure(figsize=(15, 10))  # setting the dimensions of the plot

ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender') #plotting the viz

'''for p in ax.patches:: This is a loop that iterates over each bar in the countplot. In Seaborn, when you create a countplot,
it consists of individual bars that represent the count of observations in each category of the categorical variable.

ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='baseline'): 
This line is the key part of the code where we add the count values above each bar.

ax.annotate: This is a function in Matplotlib that is used to add text annotations to a plot.

f'{p.get_height()}': This is a formatted string that contains the count value. We use p.get_height() to extract the 
height of each bar, which represents the count of observations for that category. This value is converted to a string so 
that it can be displayed as text on the plot.

(p.get_x() + p.get_width() / 2., p.get_height()): This is the position where we want to place the text annotation. 
(p.get_x() + p.get_width() / 2., p.get_height()) calculates the center position of each bar. p.get_x() returns the 
x-coordinate of the left side of the bar, and p.get_width() gives the width of the bar. By adding half of the width to the 
x-coordinate, we get the center position on the x-axis, and p.get_height() gives the y-coordinate of the top of the bar, 
which is where we want to place the text annotation.

ha='center', va='baseline': These are the horizontal and vertical alignments of the text. ha='center' means the text 
will be centered horizontally at the specified position, and va='baseline' means the text will be aligned with the 
baseline (y-coordinate) at the specified position. This ensures that the count values are displayed above the bars.'''

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()+30),
                ha='center', va='baseline')

plt.show()  #display the plot

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  Amount
# 0     Maharashtra   Western       Healthcare             Auto       1   23952
# 1  Andhra Pradesh  Southern             Govt             Auto       3   23934
# 2   Uttar Pradesh   Central       Automobile             Auto       3   23924
# 3       Karnataka  Southern     Construction             Auto       2   23912
# 4         Gujarat   Western  Food Processing             Auto       2   23877

# %%
# Total Amount by Age group

plt.figure(figsize=(10, 5))  # setting the dimensions of the plot

sales_age = df.groupby(['Age Group'],as_index = False)['Amount'].sum()

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
plt.show()

# %%
# Total Amount by age group SORTED

plt.figure(figsize=(10, 5))  # setting the dimensions of the plot

sales_age = df.groupby(['Age Group'],as_index = False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
plt.show()

# %% [markdown]
# ### State wise analysis

# %%
# Total number of orders from top 10 states SORTED

sales_state = df.groupby(['State'],as_index = False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')

# %% [markdown]
# ##### From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively

# %% [markdown]
# ### Marital Status

# %%
plt.figure(figsize=(10, 6))  # setting the dimensions of the plot

# Custom text labels for the x-axis (since the values are 0 and 1 in the data frame)
custom_labels = ['Married', 'Unmarried']

# Create the bar plot using Seaborn
ax = sns.countplot(data = df, x = 'Marital_Status') #plotting the viz

#Add the count to the top of the bar chart
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()+40),
                ha='center', va='baseline')

# Set the custom x-axis labels
plt.gca().set_xticklabels(custom_labels)

# Set the x-axis label
plt.xlabel('Marital status')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 5))  # setting the dimensions of the plot

maritalstatus_gender = df.groupby(['Marital_Status','Gender'], as_index = False)['Amount'].sum().sort_values(by = 'Amount', ascending = False)

# Custom text labels for the x-axis (since the values are 0 and 1 in the data frame)
custom_labels = ['Married', 'Unmarried']

sns.barplot(data = maritalstatus_gender, x = 'Marital_Status',y= 'Amount', hue='Gender')



# Set the custom x-axis labels
plt.gca().set_xticklabels(custom_labels)

# Set the x-axis label
plt.xlabel('Marital status')


plt.show()

# %% [markdown]
# #### From above graphs we can see that most of the buyers are married (women) and they have high purchasing power

# %% [markdown]
# ### Occupation

# %%
#Types of occupation with count in a sorted order

plt.figure(figsize=(20, 5))
ax = sns.countplot(data = df, x = 'Occupation',order=df['Occupation'].value_counts(ascending=False).index)

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()+40),
                ha='center', va='baseline')

# %%
#Occupations that have spent the most

sales_occupation = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

plt.figure(figsize=(20, 5))

sns.barplot(data = sales_occupation, x = 'Occupation',y= 'Amount')

# %% [markdown]
# #### From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector

# %% [markdown]
# ### Product Category

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11246     Maharashtra   Western         Chemical           Office       4
# 11247         Haryana  Northern       Healthcare       Veterinary       3
# 11248  Madhya Pradesh   Central          Textile           Office       4
# 11249       Karnataka  Southern      Agriculture           Office       3
# 11250     Maharashtra   Western       Healthcare           Office       3
#
#        Amount
# 0       23952
# 1       23934
# 2       23924
# 3       23912
# 4       23877
# ...       ...
# 11246     370
# 11247     367
# 11248     213
# 11249     206
# 11250     188
#
# [11239 rows x 13 columns]

# %%
#Cuount of different types of Product Category

plt.figure(figsize=(30, 10))
ax = sns.countplot(data = df, x = 'Product_Category',order=df['Product_Category'].value_counts(ascending=False).index)

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()+40),
                ha='center', va='baseline')

# %%
# Product categories that have sold the most (Top 10)

sales_product = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

plt.figure(figsize=(30, 10))

sns.barplot(data = sales_product, x = 'Product_Category',y= 'Amount')

# %% [markdown]
# #### From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category

# %%
# top 10 most sold products

fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')

# %%
correlation_matrix = df.corr()

# Create a heatmap to visualize the correlations
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11246     Maharashtra   Western         Chemical           Office       4
# 11247         Haryana  Northern       Healthcare       Veterinary       3
# 11248  Madhya Pradesh   Central          Textile           Office       4
# 11249       Karnataka  Southern      Agriculture           Office       3
# 11250     Maharashtra   Western       Healthcare           Office       3
#
#        Amount
# 0       23952
# 1       23934
# 2       23924
# 3       23912
# 4       23877
# ...       ...
# 11246     370
# 11247     367
# 11248     213
# 11249     206
# 11250     188
#
# [11239 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

# Assuming you have the dataset as a DataFrame 'df'

# Define X as the feature columns and Y as the target variable
X = df[['Gender', 'Age', 'Marital_Status', 'Zone', 'Occupation', 'Product_Category', 'Orders']]
Y = df['Amount']

# Split the data into training and testing sets (e.g., 80% for training, 20% for testing)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# 'test_size' specifies the proportion of the dataset to include in the testing set.
# 'random_state' is used to ensure reproducibility, but you can change it or set it to None.

# Now you have X_train, X_test, Y_train, and Y_test for the train-test split.

# %%
# Define a function to calculate WoE and IV
def calculate_woe_iv(df, feature, target):
    df_woe_iv = pd.DataFrame()

    total_positive = df[target].sum()
    total_negative = len(df) - total_positive

    feature_counts = df.groupby(feature)[target].agg(['count', 'sum'])
    feature_counts['negative'] = feature_counts['count'] - feature_counts['sum']

    feature_counts['woe'] = np.log(
        (feature_counts['sum'] / total_positive) / (feature_counts['negative'] / total_negative)
    )

    feature_counts['iv'] = (feature_counts['sum'] / total_positive - feature_counts['negative'] / total_negative) * feature_counts['woe']

    df_woe_iv[feature] = feature_counts['woe']
    df_woe_iv.set_index(feature, inplace=True)
    
    return df_woe_iv

# Apply WoE and IV transformation to X_train and X_test
categorical_columns = df[['Gender', 'Age', 'Marital_Status', 'Zone', 'Occupation', 'Product_Category', 'Orders']]
woe_iv_results = {}

for column in categorical_columns:
    woe_iv_results[column] = calculate_woe_iv(pd.concat([X_train, Y_train], axis=1), column, 'Amount')

# Create copies of X_train and X_test for WoE encoding
X_train_woe = X_train.copy()
X_test_woe = X_test.copy()

# Apply WoE and IV transformation using the map method
for column in woe_iv_results:
    X_train_woe[column + '_woe'] = X_train[column].map(woe_iv_results[column])
    X_test_woe[column + '_woe'] = X_test[column].map(woe_iv_results[column])

# Drop the original categorical columns
X_train_woe.drop(categorical_columns, axis=1, inplace=True)
X_test_woe.drop(categorical_columns, axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-5fc3a3015df2> in <module>
#      25
#      26 for column in categorical_columns:
# ---> 27     woe_iv_results[column] = calculate_woe_iv(pd.concat([X_train, Y_train], axis=1), column, 'Amount')
#      28
#      29 # Create copies of X_train and X_test for WoE encoding
#
# <ipython-input-53-5fc3a3015df2> in calculate_woe_iv(df, feature, target)
#       6     total_negative = len(df) - total_positive
#       7
# ----> 8     feature_counts = df.groupby(feature)[target].agg(['count', 'sum'])
#       9     feature_counts['negative'] = feature_counts['count'] - feature_counts['sum']
#      10
#
# E:\Anaconda\New folder\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# E:\Anaconda\New folder\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
#     408                 observed=observed,
# --> 409                 mutated=self.mutated,
#     410             )
#     411
#
# E:\Anaconda\New folder\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     596                 in_axis, name, level, gpr = False, None, gpr, None
#     597             else:
# --> 598                 raise KeyError(gpr)
#     599         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     600             # Add key to exclusions
#
# KeyError: 'Gender'

# %%
X_train
# Out:
#       Age  Orders Gender_woe  Marital_Status_woe  Zone_woe Occupation_woe  \
# 3629   30       3          F                   0   Central     Healthcare
# 2996   41       4          F                   0  Northern        Banking
# 4926   46       2          M                   0   Central     Healthcare
# 7511   29       4          F                   0  Northern      IT Sector
# 6057   13       3          F                   0   Western          Media
# ...   ...     ...        ...                 ...       ...            ...
# 5746   45       1          F                   0   Western           Govt
# 5203   29       4          F                   0   Central     Automobile
# 5402   85       1          F                   0   Western           Govt
# 872    20       3          F                   1   Western    Hospitality
# 7282   32       2          F                   1  Northern           Govt
#
#      Product_Category_woe
# 3629                 Food
# 2996     Footwear & Shoes
# 4926   Clothing & Apparel
# 7511   Clothing & Apparel
# 6057                 Food
# ...                   ...
# 5746      Sports Products
# 5203   Clothing & Apparel
# 5402                 Food
# 872                  Food
# 7282   Clothing & Apparel
#
# [8991 rows x 7 columns]
